# %%
# 1. 라이브러리 임포트 및 API 키 설정
# ===================================================================
import os
import urllib.request
import datetime
import json
import time
import ssl # HTTPS 인증서 문제를 우회하기 위해 추가
import socket # 타임아웃 설정을 위해 추가

# 🚨 중요: 본인의 Naver API ID와 Secret Key를 입력하세요.
client_id = 'Kc65Ibtu71R5TLRUF7lL'
client_secret = 'CdT4sLf9Ht' # ⬅️ 여기에 본인의 Secret Key를 입력하세요.

# HTTPS 인증서 검증 비활성화 (전역 설정)
ssl._create_default_https_context = ssl._create_unverified_context

# ===================================================================
# 2. 기본 함수 정의 (filter 파라미터 추가)
# API URL에 요청을 보내고 응답을 받아오는 함수
def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    # --- 추가된 부분: 웹 브라우저인 척 하기 위한 헤더 ---
    req.add_header("User-Agent", "Mozilla/5.0")

    try:
        # --- 핵심 변경 부분: timeout=10 설정 ---
        # 10초 안에 응답이 없으면 예외를 발생시키고 다음으로 넘어감
        response = urllib.request.urlopen(req, timeout=10)
        if response.getcode() == 200:
            return response.read().decode('utf-8')
    except Exception as e:
        print(f"[{datetime.datetime.now()}] API 요청 실패: {e} | URL: {url}")
        return None

# --- 핵심 변경 부분: filter 인자 추가 ---
def getNaverImageSearch(srcText, start, display, img_filter='large'):
    base = "https://openapi.naver.com/v1/search/image"
    parameters = f"?query={urllib.parse.quote(srcText)}&start={start}&display={display}&filter={img_filter}"
    url = base + parameters
    return getRequestUrl(url)


# 네이버 이미지 검색 API를 호출하는 함수
# --- 핵심 변경 부분: filter 인자 추가 ---
def getNaverImageSearch(srcText, start, display, img_filter='large'):
    base = "https://openapi.naver.com/v1/search/image"
    parameters = f"?query={urllib.parse.quote(srcText)}&start={start}&display={display}&filter={img_filter}"
    url = base + parameters
    return getRequestUrl(url)

# ===================================================================
# 3. 이미지 크롤링 실행 (메인 로직)
# ===================================================================
# 검색할 키워드 목록
KEYWORDS = ["뿌팟퐁커리", "팟타이", "분짜"]
# 각 키워드당 다운로드할 이미지 개수
NUM_IMAGES = 400
# 이미지를 저장할 최상위 폴더 이름
SAVE_DIR = "4_naver_crawled_images1"

print("🚀 Naver 이미지 크롤링을 시작합니다...")

for keyword in KEYWORDS:
    print(f"\n[INFO] '{keyword}' 이미지 다운로드를 시작합니다...")
    download_path = os.path.join(SAVE_DIR, keyword)
    os.makedirs(download_path, exist_ok=True)

    success_count = 0
    start_index = 1
    display_size = 100

    while success_count < NUM_IMAGES and start_index < 1000:
        print(f"   -> API 요청: 시작 위치 {start_index}")

        json_string = getNaverImageSearch(keyword, start_index, display_size, img_filter='large')
        if json_string is None:
            break

        response_dict = json.loads(json_string)

        if 'items' not in response_dict or not response_dict['items']:
            print("   -> 더 이상 검색 결과가 없습니다. 다운로드를 중단합니다.")
            break

        for item in response_dict['items']:
            if success_count >= NUM_IMAGES:
                break

            try:
                image_url = item['link']
                clean_url = image_url.split('?')[0]
                file_ext = os.path.splitext(clean_url)[1] or '.jpg'
                filename = f"{keyword}_{success_count + 1}{file_ext}"
                save_path = os.path.join(download_path, filename)

                req = urllib.request.Request(image_url, headers={"User-Agent": "Mozilla/5.0"})
                # --- 핵심 변경 부분: timeout=10 설정 ---
                with urllib.request.urlopen(req, timeout=10) as response, open(save_path, 'wb') as out_file:
                    out_file.write(response.read())

                success_count += 1

            except socket.timeout:
                print(f"   -> 다운로드 실패 (Timeout): {image_url}")
            except Exception as e:
                print(f"   -> 다운로드 실패: {image_url} | 오류: {type(e).__name__}")

        start_index += display_size
        time.sleep(0.2)

    print(f"✅ '{keyword}' 이미지 {success_count}장 다운로드 완료! -> 저장 경로: {download_path}")

print("\n🎉 모든 Naver 이미지 크롤링 작업이 완료되었습니다.")
# Out:
# 🚀 Naver 이미지 크롤링을 시작합니다...
#
# [INFO] '뿌팟퐁커리' 이미지 다운로드를 시작합니다...
#    -> API 요청: 시작 위치 1
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/034/048/d65437be8115189cf060cf8c01e06ec6.JPG | 오류: URLError
#    -> 다운로드 실패 (Timeout): http://recipe.ezmember.co.kr/cache/recipe/2018/07/19/b2b4a96aebe26e6d72a4350c35216eb01.jpg
#    -> 다운로드 실패: http://www.megamart.com/attach/product_images/pro_ed_images/8801052/IMG_6591.jpg | 오류: HTTPError
#    -> API 요청: 시작 위치 101
#    -> 다운로드 실패: https://img1.daumcdn.net/thumb/R720x0.q80/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9936CD4D5E6CFFFA44 | 오류: HTTPError
#    -> 다운로드 실패: https://cdn.clien.net/web/api/file/F01/5803505/c031dcbe6ec51.jpg?w=780&h=30000&gif=true | 오류: URLError
#    -> 다운로드 실패: https://thumb.ad.co.kr/ad/w/54/2b/a0/01/i/2079745.jpg | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): https://semie.cooking/image/board/cooking/hb/ce/bsgwbrjh/148167169gguz.jpg
#    -> 다운로드 실패: http://down.humoruniv.com/hwiparambbs/data/pdswait/a_w5ae89b001_13edcf0deade894fd3d88ea396322fac5a3c5c49.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://cdn.ppomppu.co.kr/zboard/data3/2023/0220/20230220101720_HhPx29jktw.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/4q6gbbfhC2fxOy6poe4iapOVj3w=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1547918294529_IMG_6933.jpg | 오류: URLError
#    -> 다운로드 실패 (Timeout): https://shop-phinf.pstatic.net/20250306_108/1741222820675QtO0i_PNG/90945200733211833_1665886114.png
#    -> 다운로드 실패 (Timeout): http://shop1.phinf.naver.net/20240112_203/1705021586619O9Hq3_JPEG/8394994606267823_18943887.jpeg
#    -> API 요청: 시작 위치 201
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/Sy53GTEGGgV4e2qKot4rhHjVZxI=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1469681578870_IMG_0399.JPG | 오류: URLError
#    -> 다운로드 실패: https://img-wishbeen.akamaized.net/post/1548944698152_image | 오류: URLError
#    -> 다운로드 실패 (Timeout): https://i3.ruliweb.com/img/23/09/07/18a6d117dfc9f9.jpg
#    -> 다운로드 실패: https://img1.daumcdn.net/thumb/R800x0/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9936CD4D5E6CFFFA44 | 오류: HTTPError
#    -> 다운로드 실패: http://file2.instiz.net/data/file2/2017/09/27/8/0/f/80fac94bbeeb8f81da7055df0f255cd7.jpg | 오류: URLError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/GBakaZ8LhJ9AG-U7Ag4BQDrWCBQ=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1547918464462_IMG_6936.jpg | 오류: URLError
#    -> API 요청: 시작 위치 301
#    -> 다운로드 실패: https://cdn.ppomppu.co.kr/zboard/data3/2023/0220/900w_20230220101720_HhPx29jktw.jpg | 오류: HTTPError
#    -> 다운로드 실패: http://c.huv.kr/c/84/845cf508e22607de200913baec488846dcede24b.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/0FbwzrL7MkKNxwrzjOlDiJPjVUU=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1524634169341_IMG_3713.jpg | 오류: URLError
#    -> 다운로드 실패: https://extmovie.maxmovie.com/xe/files/attach/images/14322815/751/668/018/455a21e9babc6132860a0ec905aba766.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://scontent-nrt1-2.cdninstagram.com/v/t51.2885-15/43818206_292162074721030_8891256916559982819_n.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://thumb.wishbeen.com/2LPXyeSX7ZKJ2OBkg6n_LLpR4r0=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1508779523573_SAM_5791.JPG | 오류: URLError
#    -> 다운로드 실패: http://image.g9.co.kr/g/1527059294/n?ts=15579812037000000 | 오류: URLError
#    -> 다운로드 실패: https://img1.daumcdn.net/thumb/R720x0.q80/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9968414E5E6CFEE311 | 오류: HTTPError
#    -> API 요청: 시작 위치 401
#    -> 다운로드 실패 (Timeout): https://i2.ruliweb.com/img/23/07/04/1891f402bbc36698.jpg
# ✅ '뿌팟퐁커리' 이미지 400장 다운로드 완료! -> 저장 경로: 4_naver_crawled_images1\뿌팟퐁커리
#
# [INFO] '팟타이' 이미지 다운로드를 시작합니다...
#    -> API 요청: 시작 위치 1
#    -> 다운로드 실패: https://scontent-nrt1-1.cdninstagram.com/v/t51.29350-15/451952705_428375656862814_5424774017827352225_n.webp | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): http://shop1.phinf.naver.net/20230404_199/1680581123296SAjMM_JPEG/81716951088976787_2127970447.jpeg
#    -> 다운로드 실패 (Timeout): https://upload.wikimedia.org/wikipedia/commons/3/39/Phat_Thai_kung_Chang_Khien_street_stall.jpg
#    -> 다운로드 실패: http://image.g9.co.kr/g/1675123037/n?ts=15694309956830000 | 오류: URLError
#    -> 다운로드 실패: http://www.megamart.com/attach/product_images/pro_ed_images/8801052/IMG_8548.jpg | 오류: HTTPError
#    -> API 요청: 시작 위치 101
#    -> 다운로드 실패: https://i2.ruliweb.com/img/23/05/05/187ec5480de13ebfe.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://thumb.wishbeen.com/nOBbtuvsTUSZQDDJn7MTCgCFkN4=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1508782615489_SAM_5989.JPG | 오류: URLError
#    -> 다운로드 실패: http://c.huv.kr/c/bf/bfc34b5958bbd750ccd047f13635dbc6a4a1302a.jpg | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1c/d1/28/b3/20210404-134321-largejpg.jpg?w=900&h=500&s=1
#    -> 다운로드 실패: https://img1.daumcdn.net/thumb/R720x0.q80/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9976B2485A6AF11427 | 오류: HTTPError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/peX4AXB3OjVyNB6yYqCzo10fy1U=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1568964636583_PC180993.JPG | 오류: URLError
#    -> API 요청: 시작 위치 201
#    -> 다운로드 실패: https://blog.kakaocdn.net/dna/bt3kCg/btrJRucpEzI/AAAAAAAAAAAAAAAAAAAAAO1SATGMp9uC3cwCTMtgoD9eRGJP6Ur910NUDCL-n1Uw/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1756652399&allow_ip=&allow_referer=&signature=cAhIKaOdABBEU6lMeTbXU4Vd%2BsI%3D | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): https://cdn2.wadiz.kr/2024/10/04/c16dc709-3ab6-4609-a674-dfe36a55c373.jpg/wadiz/resize/1200/format/jpg/quality/80/
#    -> 다운로드 실패 (Timeout): https://gigglehd.com/gg/files/attach/images/158/672/925/010/e43d00bb7987ce3dfba9b05e2900be5a.jpeg
#    -> API 요청: 시작 위치 301
#    -> 다운로드 실패: https://img-wishbeen.akamaized.net/post/1521771209861_02060685.jpg | 오류: URLError
#    -> 다운로드 실패: https://img1.daumcdn.net/thumb/R720x0.q80/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F993219435B0713521E | 오류: HTTPError
#    -> 다운로드 실패: https://www.ck.ac.kr/wp-content/uploads/2023/10/20231007_082239.jpg | 오류: URLError
#    -> API 요청: 시작 위치 401
#    -> 다운로드 실패 (Timeout): http://imgnews.naver.net/image/5353/2025/01/22/0000982690_001_20250122183616945.jpg
# ✅ '팟타이' 이미지 400장 다운로드 완료! -> 저장 경로: 4_naver_crawled_images1\팟타이
#
# [INFO] '분짜' 이미지 다운로드를 시작합니다...
#    -> API 요청: 시작 위치 1
#    -> 다운로드 실패: http://down.humoruniv.com/hwiparambbs/data/pdswait/a_wb2637b001_0517a66e10fb7a22dd63b74445f22d5a3706602d.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://thumb.wishbeen.com/gtH1_KH9N3dI-ZEvW63azcShVNQ=/880x/smart/filters:no_upscale()/wishbeen-seoul.s3.ap-northeast-2.amazonaws.com/post/1513334124025_IMG_3730.JPG | 오류: URLError
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/742/099/dc33eb65a6cd59957d91ec3133145611.JPG | 오류: URLError
#    -> 다운로드 실패 (Timeout): http://imgnews.naver.net/image/5284/2019/06/14/0000234169_002_20190614120625532.jpg
#    -> API 요청: 시작 위치 101
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/r7ztjkLXsH_CBpV3W5mMiYVuj_s=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1539014341492_20181007_115042_HDR.jpg | 오류: URLError
#    -> 다운로드 실패: https://extmovie.maxmovie.com/xe/files/attach/images/148/668/721/038/0e76b9b15bf38d2d85effe6cab7bc87f.jpg | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): http://imgnews.naver.net/image/5310/2021/09/27/0000028286_003_20250521012717839.jpg
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/012/081/6364fe456e938153463cfab9b7d6a2c3.JPG | 오류: URLError
#    -> 다운로드 실패: https://data.ygosu.com/upload_files/board_food/37118/5acf8589a13b0.jpeg | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): https://d2uja84sd90jmv.cloudfront.net/posts/kshD5uvZMerrvnN-sQ3YTA/ms.jpg
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/685/100/3019bd3047b3d853889e58b3175992df.JPG | 오류: URLError
#    -> 다운로드 실패 (Timeout): https://d2uja84sd90jmv.cloudfront.net/posts/Wo_5XdHBVvaatOGZVhRaLg/ms.jpg
#    -> 다운로드 실패: https://cdn.clien.net/web/api/file/F01/9069092/3fbf2412c03df0.png | 오류: URLError
#    -> API 요청: 시작 위치 201
#    -> 다운로드 실패: https://thumb.wishbeen.com/XO2olAn03w7nAuXf6hzOo8dOIeg=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1518314735100_KakaoTalk_20180211_103936279.jpg | 오류: URLError
#    -> 다운로드 실패: https://extmovie.maxmovie.com/xe/files/attach/images/148/668/721/038/0e76b9b15bf38d2d85effe6cab7bc87f.jpg | 오류: HTTPError
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/685/100/3019bd3047b3d853889e58b3175992df.JPG | 오류: URLError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/wU7c-1JAXCqb-qkQSVtxJWa01Wo=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1574144624631_01310974.JPG | 오류: URLError
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/012/081/6364fe456e938153463cfab9b7d6a2c3.JPG | 오류: URLError
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/742/099/ec7fc3fc2b67a07a16202afbfc652fa5.JPG | 오류: URLError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/hGSOtgjdm8ERCtb5vmhVlcMyaSM=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1490762031586_DSC07349.JPG | 오류: URLError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/WzbwDR7cSPx3wx-KW-rvMEiPmZs=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1546415469536_P20181215_175223626_E2326A4F-5990-46A8-9C86-4B5A136DB2DB.jpg | 오류: URLError
#    -> API 요청: 시작 위치 301
#    -> 다운로드 실패: https://cdn.clien.net/web/api/file/F01/6774906/54247b8a91b72a.png | 오류: URLError
#    -> 다운로드 실패: https://img.extmovie.com/files/attach/images/148/118/210/050/2ba3669d8e0ed0a612b7850355a6c1cf.jpeg | 오류: HTTPError
#    -> 다운로드 실패: https://homecuisine.co.kr/files/attach/images/142/798/082/7a9cd5af45f0318fefda72f48a55404e.JPG | 오류: URLError
#    -> 다운로드 실패 (Timeout): http://cdn.ppomppu.co.kr/zboard/data3/2018/0826/20180826162303_qnbsvcfa.jpg
#    -> 다운로드 실패: https://scontent-nrt1-2.cdninstagram.com/v/t51.36329-15/365402084_1173489614041473_5823838284740547690_n.jpg | 오류: HTTPError
#    -> 다운로드 실패 (Timeout): https://d2uja84sd90jmv.cloudfront.net/posts/HZFZlpcOWRD6Yb-8eiHaCg/m.jpg
#    -> 다운로드 실패: https://img-wishbeen.akamaized.net/post/1539014446096_20181007_121712_HDR.jpg | 오류: URLError
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/qEbWsGMrxNAy6m4wE27HHczAehM=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1485182670847_34a20892-348c-4371-adeb-7ca7b4901a14.jpg | 오류: URLError
#    -> 다운로드 실패 (Timeout): https://img1.daumcdn.net/thumb/R1280x0.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/3gMP/image/CViEg0RyW6YK13rpvcl103M67vk.jpg
#    -> API 요청: 시작 위치 401
#    -> 다운로드 실패: https://thumb-wishbeen.akamaized.net/25-LbZVxOx0_QnMIjQ5jk7mN1-0=/880x/smart/filters:no_upscale()/img-wishbeen.akamaized.net/post/1491163225783_image | 오류: URLError
# ✅ '분짜' 이미지 400장 다운로드 완료! -> 저장 경로: 4_naver_crawled_images1\분짜
#
# 🎉 모든 Naver 이미지 크롤링 작업이 완료되었습니다.
